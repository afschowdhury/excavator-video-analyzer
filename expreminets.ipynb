# %%
from prompts import PromptManager

# Test loading POML templates after fixing syntax errors
prompt_manager = PromptManager()
print("✓ All POML templates loaded successfully!")
# Out:
# ✓ All POML templates loaded successfully!

# %%
prompt_manager.list_prompts()
# Out:
# {'simple': 'Basic analysis focusing on key performance metrics',
#  'detailed': 'Comprehensive analysis with detailed breakdowns',
#  'comprehensive_analysis': 'POML-based Comprehensive Analysis template',
#  'simple_analysis': 'POML-based Simple Analysis template',
#  'cycle_detection': 'POML-based Cycle Detection template',
#  'technique_evaluation': 'POML-based Technique Evaluation template'}

# %%
cycle_detection_prompt = prompt_manager.get_prompt("cycle_detection")
print(cycle_detection_prompt)
# Out:
# Role: You are an expert excavator cycle time analyst with extensive experience in analyzing excavator operations and measuring productivity metrics. You specialize in frame-by-frame video analysis to identify precise timing patterns.
#
# Task: Analyze the ENTIRE video systematically and identify ALL complete dig-dump cycles from start to finish.
#
#     A complete dig-dump cycle consists of four distinct phases:
#     1. **Dig Phase**: Excavator bucket descends, penetrates material, and fills with load
#     2. **Swing to Dump**: Loaded excavator swings from dig location to dump location
#     3. **Dump Phase**: Bucket opens and releases material at dump location
#     4. **Return Swing**: Empty excavator swings back to dig location to start next cycle
#
#     Watch the COMPLETE video from start to finish and identify EVERY complete cycle (all 4 phases present).
#
#
# Examples:
#
# Example 1:
# **Cycle 1**
#     - Start Time: 00:15.2
#     - End Time: 00:47.8
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 cycle_detection_prompt.config
#
# AttributeError: 'str' object has no attribute 'config'
